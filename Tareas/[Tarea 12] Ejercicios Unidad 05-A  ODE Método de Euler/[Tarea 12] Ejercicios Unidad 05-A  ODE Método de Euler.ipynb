# %%
# %load_ext autoreload

# %% [markdown]
# # ESCUELA POLITECNICA NACIONAL
# - Nombre: Moisés Pineda
# - Curso: GR1CC
# - Fecha: 06/08/2025

# %% [markdown]
# ## REPOSITORIO. -
#
# Link: https://github.com/SantiagoTmg/Metodos_Numericos_GRCC1/tree/main/Tareas/%5BTarea%2012%5D%20Ejercicios%20Unidad%2005-A%20%20ODE%20M%C3%A9todo%20de%20Euler

# %% [markdown]
# # [Tarea 12] Ejercicios Unidad 05-A | ODE Método de Euler

# %% [markdown]
# ## CONJUNTO DE EJERCICIOS. -

# %% [markdown]
# ### 1. Use el método de Euler para aproximar las soluciones para cada uno de los siguientes problemas de valor inicial.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### EJERICICIO A)

# %%
# %autoreload 2
from ODE import ODE_euler
from math import exp
f_a= lambda t, y: t*exp(3 * t) - 2*y 
a=0
b=1
y_t0=0
N = int((b - a) / 0.5)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_a, N=N)
ys
# Out:
# [0, 0.0, 1.1204222675845161]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERICICO B)

# %%
# %autoreload 2
from ODE import ODE_euler
f_b = lambda t, y: 1 +(t-y)**2
a=2
b=3
y_t0=1
N = int((b - a) / 0.5)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_b, N=N)
ys
# Out:
# [1, 2.0, 2.625]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO C)

# %%
# %autoreload 2
from ODE import ODE_euler
f_c = lambda t,y: 1 + y/t
a=1
b=2
y_t0=2
N = int((b - a) / 0.25)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_c, N=N)
ys
# Out:
# [2, 2.75, 3.55, 4.391666666666667, 5.269047619047619]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()

# %% [markdown]
# #### EJRCICIO D)

# %%
# %autoreload 2
from ODE import ODE_euler
from math import cos, sin
f_d = lambda t, y: cos(2*t) + sin(3*t)
a=0
b=1
y_t0=1
N = int((b - a) / 0.25)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_d, N=N)
ys
# Out:
# [1, 1.25, 1.6398053304784268, 2.0242546535964756, 2.2364572532353817]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()

# %% [markdown]
# ### 2. Las soluciones reales para los problemas de valor inicial en el ejercicio 1 se proporcionan aquí. Compare el error real en cada paso.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### EJERCICIO A)

# %%
# %autoreload 2
from math import exp
f_a= lambda t, y: t*exp(3 * t) - 2*y
f_ex_a= lambda t: (1/5) * t * exp(3 * t) - (1/25) * exp(3 * t) + (1/25) * exp(-2 * t)
a=0
b=1
y_t0=0
N = int((b - a) / 0.5)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_a, N=N)
ys_exact = [f_ex_a(t) for t in ts]
errors = [abs(ys_exact[i] - ys[i]) for i in range(len(ts))]
print("Aproximación:", ys)
print("Exacta:", ys_exact)
print("Errores en cada paso:", errors)
# Out:
# Aproximación: [0, 0.0, 1.1204222675845161]
# Exacta: [0.0, 0.2836165218671416, 3.2190993190394916]
# Errores en cada paso: [0.0, 0.2836165218671416, 2.0986770514549757]

# %%
import matplotlib.pyplot as plt
plt.plot(ts, ys, 'o-', label='Aproximación con Euler')
plt.plot(ts, ys_exact, 'x-', label='Solución exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title("Comparación entre la aproximación de Euler y la solución exacta")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### EJERICICIO B)

# %%
# %autoreload 2
f_b = lambda t, y: 1 +(t-y)**2 
f_ex_b = lambda t: t + 1/(1-t)
a=2
b=3
y_t0=1
N = int((b - a) / 0.5)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_b, N=N)
ys_exact = [f_ex_b(t) for t in ts]
errors = [abs(ys_exact[i] - ys[i]) for i in range(len(ts))]
print("Aproximación:", ys)
print("Exacta:", ys_exact)
print("Errores en cada paso:", errors)
# Out:
# Aproximación: [1, 2.0, 2.625]
# Exacta: [1.0, 1.8333333333333335, 2.5]
# Errores en cada paso: [0.0, 0.16666666666666652, 0.125]

# %%
import matplotlib.pyplot as plt
plt.plot(ts, ys, 'o-', label='Aproximación con Euler')
plt.plot(ts, ys_exact, 'x-', label='Solución exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title("Comparación entre la aproximación de Euler y la solución exacta")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### EJERICICIO C)

# %%
# %autoreload 2
from math import log
f_c = lambda t,y: 1 + y/t
f_ex_c=lambda t: t * log(t) + 2 * t
a=1
b=2
y_t0=2
N = int((b - a) / 0.25)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_c, N=N)
ys_exact = [f_ex_c(t) for t in ts]
errors = [abs(ys_exact[i] - ys[i]) for i in range(len(ts))]
print("Aproximación:", ys)
print("Exacta:", ys_exact)
print("Errores en cada paso:", errors)
# Out:
# Aproximación: [2, 2.75, 3.55, 4.391666666666667, 5.269047619047619]
# Exacta: [2.0, 2.7789294391427624, 3.6081976621622465, 4.47932762888699, 5.386294361119891]
# Errores en cada paso: [0.0, 0.02892943914276236, 0.058197662162246644, 0.08766096222032349, 0.11724674207227181]

# %%
import matplotlib.pyplot as plt
plt.plot(ts, ys, 'o-', label='Aproximación con Euler')
plt.plot(ts, ys_exact, 'x-', label='Solución exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title("Comparación entre la aproximación de Euler y la solución exacta")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### EJERCICIO D)

# %%
# %autoreload 2
from math import sin, cos
f_d = lambda t, y: cos(2*t) + sin(3*t)
f_ex_d = lambda t: (1/2) * sin(2 * t) - (1/3) * cos(3 * t) + (4/3) * t
a=0
b=1
y_t0=1
N = int((b - a) / 0.25)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_d, N=N)
ys_exact = [f_ex_d(t) for t in ts]
errors = [abs(ys_exact[i] - ys[i]) for i in range(len(ts))]
print("Aproximación:", ys)
print("Exacta:", ys_exact)
print("Errores en cada paso:", errors)
# Out:
# Aproximación: [1, 1.25, 1.6398053304784268, 2.0242546535964756, 2.2364572532353817]
# Exacta: [-0.3333333333333333, 0.32914981301082785, 1.0638230918480471, 1.7081387008762736, 2.1179795456129895]
# Errores en cada paso: [1.3333333333333333, 0.9208501869891721, 0.5759822386303797, 0.316115952720202, 0.11847770762239218]

# %%
import matplotlib.pyplot as plt
plt.plot(ts, ys, 'o-', label='Aproximación con Euler')
plt.plot(ts, ys_exact, 'x-', label='Solución exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title("Comparación entre la aproximación de Euler y la solución exacta")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. Utilice el método de Euler para aproximar las soluciones para cada uno de los siguientes problemas de valor inicial.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### EJERCICIO A)

# %%
# %autoreload 2
from ODE import ODE_euler
f_a= lambda t, y: y/t - (y/t)**2 
a=1
b=2
y_t0=1
N = int((b - a) / 0.1)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_a, N=N)
ys
# Out:
# [1,
#  1.0,
#  1.0082644628099173,
#  1.0216894717270375,
#  1.038514734248178,
#  1.0576681921408762,
#  1.0784610936317547,
#  1.100432164699466,
#  1.1232620515812632,
#  1.1467235965295264,
#  1.1706515695646647]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO B)

# %%
# %autoreload 2
from ODE import ODE_euler
f_b= lambda t, y: 1+y/t+(y/t)**2
a=1
b=3
y_t0=0
N = int((b - a) / 0.2)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_b, N=N)
ys
# Out:
# [0,
#  0.2,
#  0.4388888888888889,
#  0.721242756361804,
#  1.0520380316573712,
#  1.4372511475238394,
#  1.8842608053291532,
#  2.402269588561542,
#  3.0028371645572136,
#  3.7006007049327985,
#  4.5142774281767]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO C)

# %%
# %autoreload 2
from ODE import ODE_euler
f_c = lambda t, y: -(y+1)*(y+3)
a=0
b=2
y_t0=-2
N = int((b - a) / 0.2)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_c, N=N)
ys
# Out:
# [-2,
#  -1.8,
#  -1.608,
#  -1.4387328000000001,
#  -1.3017369739591682,
#  -1.199251224666308,
#  -1.1274909449059896,
#  -1.079745355150198,
#  -1.0491190774237251,
#  -1.0299539832076265,
#  -1.0181518381465764]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO D)

# %%
# %autoreload 2
from ODE import ODE_euler
f_d = lambda t, y: -5*y + 5*t**2 + 2*t
a=0
b=1
y_t0=1/3
N = int((b - a) / 0.1)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_d, N=N)
ys
# Out:
# [0.3333333333333333,
#  0.16666666666666666,
#  0.10833333333333334,
#  0.11416666666666667,
#  0.16208333333333336,
#  0.2410416666666667,
#  0.34552083333333333,
#  0.4727604166666667,
#  0.6213802083333333,
#  0.7906901041666666,
#  0.9803450520833332]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()

# %% [markdown]
# ### 4. Aquí se dan las soluciones reales para los problemas de valor inicial en el ejercicio 3. Calcule el error real en las aproximaciones del ejercicio 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### EJERCICIO A)

# %%
# %autoreload 2
from math import log
f_a= lambda t, y: y/t - (y/t)**2 
f_ex_a=lambda t: t/ (1 + log(t))
a=1
b=2
y_t0=1
N = int((b - a) / 0.1)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_a, N=N)
ys_exact = [f_ex_a(t) for t in ts]
errors = [abs(ys_exact[i] - ys[i]) for i in range(len(ts))]
print("Aproximación:", ys)
print("Exacta:", ys_exact)
# Out:
# Aproximación: [1, 1.0, 1.0082644628099173, 1.0216894717270375, 1.038514734248178, 1.0576681921408762, 1.0784610936317547, 1.100432164699466, 1.1232620515812632, 1.1467235965295264, 1.1706515695646647]
# Exacta: [1.0, 1.0042817279362024, 1.0149523140337415, 1.0298136889579848, 1.0475339192525197, 1.067262354181873, 1.088432686945791, 1.1106550521462644, 1.1336535567333055, 1.1572284330546696, 1.1812322182992827]

# %%
import matplotlib.pyplot as plt
plt.plot(ts, ys, 'o-', label='Aproximación con Euler')
plt.plot(ts, ys_exact, 'x-', label='Solución exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title("Comparación entre la aproximación de Euler y la solución exacta")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### EJERCICIO B)

# %%
# %autoreload 2
from math import log,tan
f_b= lambda t, y: 1+y/t+(y/t)**2
f_ex_b=lambda t: t * tan (log(t))
a=1
b=3
y_t0=0
N = int((b - a) / 0.2)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_b, N=N)
ys_exact = [f_ex_b(t) for t in ts]
errors = [abs(ys_exact[i] - ys[i]) for i in range(len(ts))]
print("Aproximación:", ys)
print("Exacta:", ys_exact)
# Out:
# Aproximación: [0, 0.2, 0.4388888888888889, 0.721242756361804, 1.0520380316573712, 1.4372511475238394, 1.8842608053291532, 2.402269588561542, 3.0028371645572136, 3.7006007049327985, 4.5142774281767]
# Exacta: [0.0, 0.22124277275763113, 0.48968166375094263, 0.812752740561542, 1.19943864032594, 1.661281755721567, 2.213501813480633, 2.8765514199948425, 3.6784753308518447, 4.658665058239517, 5.874099978184171]

# %%
import matplotlib.pyplot as plt
plt.plot(ts, ys, 'o-', label='Aproximación con Euler')
plt.plot(ts, ys_exact, 'x-', label='Solución exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title("Comparación entre la aproximación de Euler y la solución exacta")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### EJERCICIO C)

# %%
# %autoreload 2
from math import exp
f_c = lambda t, y: -(y+1)*(y+3)
f_ex_c = lambda t: -3 + 2/(1 + exp(-2 * t))
a=0
b=2
y_t0=-2
N = int((b - a) / 0.2)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_c, N=N)
ys_exact = [f_ex_c(t) for t in ts]
errors = [abs(ys_exact[i] - ys[i]) for i in range(len(ts))]
print("Aproximación:", ys)
print("Exacta:", ys_exact)
# Out:
# Aproximación: [-2, -1.8, -1.608, -1.4387328000000001, -1.3017369739591682, -1.199251224666308, -1.1274909449059896, -1.079745355150198, -1.0491190774237251, -1.0299539832076265, -1.0181518381465764]
# Exacta: [-2.0, -1.802624679775096, -1.620051037744775, -1.4629504330019645, -1.335963229732151, -1.2384058440442354, -1.1663453929878447, -1.1146483517977375, -1.0783314455935287, -1.053193987153732, -1.035972419924183]

# %%
import matplotlib.pyplot as plt
plt.plot(ts, ys, 'o-', label='Aproximación con Euler')
plt.plot(ts, ys_exact, 'x-', label='Solución exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title("Comparación entre la aproximación de Euler y la solución exacta")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### EJERCICIO D)

# %%
# %autoreload 2
from math import exp
f_d = lambda t, y: -5*y + 5*t**2 + 2*t
f_ex_d = lambda t: t**2 + (1/3) * exp(-5 * t)
a=0
b=1
y_t0=1/3
N = int((b - a) / 0.1)
ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f_d, N=N)
ys_exact = [f_ex_d(t) for t in ts]
errors = [abs(ys_exact[i] - ys[i]) for i in range(len(ts))]
print("Aproximación:", ys)
print("Exacta:", ys_exact)
# Out:
# Aproximación: [0.3333333333333333, 0.16666666666666666, 0.10833333333333334, 0.11416666666666667, 0.16208333333333336, 0.2410416666666667, 0.34552083333333333, 0.4727604166666667, 0.6213802083333333, 0.7906901041666666, 0.9803450520833332]
# Exacta: [0.3333333333333333, 0.2121768865708778, 0.16262648039048078, 0.16437672004947662, 0.2051117610788709, 0.27736166620796626, 0.3765956894559546, 0.5000657944741062, 0.6461052129629113, 0.8137029988460805, 1.0022459823330283]

# %%
import matplotlib.pyplot as plt
plt.plot(ts, ys, 'o-', label='Aproximación con Euler')
plt.plot(ts, ys_exact, 'x-', label='Solución exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title("Comparación entre la aproximación de Euler y la solución exacta")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 5. Utilice los resultados del ejercicio 3 y la interpolación lineal para aproximar los siguientes valores de 𝑦(𝑡). Compare las aproximaciones asignadas para los valores reales obtenidos mediante las funciones determinadas en el ejercicio 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### EJERCICIO A)

# %%
# %autoreload 2
from ODE import interpolacion_lineal

y_1 = [1,
 1.0,
 1.0082644628099173,
 1.0216894717270375,
 1.038514734248178,
 1.0576681921408762,
 1.0784610936317547,
 1.100432164699466,
 1.1232620515812632,
 1.1467235965295264,
 1.1706515695646647]
y_2 =[1.0,
     1.0042817279362024,
     1.0149523140337415,
     1.0298136889579848,
     1.0475339192525197,
     1.067262354181873,
     1.088432686945791,
     1.1106550521462644,
     1.1336535567333055,
     1.1572284330546696,
     1.1812322182992827]

x_val = [0.25,0.93]
y_val = interpolacion_lineal(y_1, y_2, x_val)
print(f"El valor interpolado en x = {x_val} es y = {y_val}")
# Out:
# El valor interpolado en x = [0.25, 0.93] es y = [-inf -inf]
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\interpolate\_interpolate.py:479: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]

# %% [markdown]
# #### EJERCICIO B)

# %%
# %autoreload 2
from ODE import interpolacion_lineal

y_1 = [0,
 0.2,
 0.4388888888888889,
 0.721242756361804,
 1.0520380316573712,
 1.4372511475238394,
 1.8842608053291532,
 2.402269588561542,
 3.0028371645572136,
 3.7006007049327985,
 4.5142774281767]
y_2 =[0.0,
     0.22124277275763113,
     0.48968166375094263,
     0.812752740561542,
     1.19943864032594,
     1.661281755721567,
     2.213501813480633,
     2.8765514199948425,
     3.6784753308518447, 
     4.658665058239517,
     5.874099978184171]

x_val = [1.25,1.93]
y_val = interpolacion_lineal(y_1, y_2, x_val)
print(f"El valor interpolado en x = {x_val} es y = {y_val}")
# Out:
# El valor interpolado en x = [1.25, 1.93] es y = [1.43678095 2.27204784]

# %% [markdown]
# #### EJERCICIO C)

# %%
# %autoreload 2
from ODE import interpolacion_lineal

y_1 = [-2,
     -1.8,
     -1.608,
     -1.4387328000000001,
     -1.3017369739591682,
     -1.199251224666308,
     -1.1274909449059896,
     -1.079745355150198,
     -1.0491190774237251,
     -1.0299539832076265,
     -1.0181518381465764]

y_2 = [-2.0,
     -1.802624679775096,
     -1.620051037744775,
     -1.4629504330019645,
     -1.335963229732151,
     -1.2384058440442354,
     -1.1663453929878447,
     -1.1146483517977375,
     -1.0783314455935287,
     -1.053193987153732,
     -1.035972419924183]

x_val = [2.10,2.75]
y_val = interpolacion_lineal(y_1, y_2, x_val)
print(f"El valor interpolado en x = {x_val} es y = {y_val}")
# Out:
# El valor interpolado en x = [2.1, 2.75] es y = [3.51400229 4.46247552]

# %% [markdown]
# #### EJERCICIO D)

# %%
# %autoreload 2
from ODE import interpolacion_lineal

y_1 = [0.3333333333333333,
       0.16666666666666666,
       0.10833333333333334,
       0.11416666666666667,
       0.16208333333333336,
       0.2410416666666667,
       0.34552083333333333,
       0.4727604166666667,
       0.6213802083333333,
       0.7906901041666666,
       0.9803450520833332]

y_2 = [0.3333333333333333,
       0.2121768865708778,
       0.16262648039048078,
       0.16437672004947662,
       0.2051117610788709,
       0.27736166620796626,
       0.3765956894559546,
       0.5000657944741062,
       0.6461052129629113,
       0.8137029988460805,
       1.0022459823330283]

x_val = [0.54,0.94]
y_val = interpolacion_lineal(y_1, y_2, x_val)
print(f"El valor interpolado en x = {x_val} es y = {y_val}")
# Out:
# El valor interpolado en x = [0.54, 0.94] es y = [0.56613795 0.96213748]

# %% [markdown]
# ### 6. Use el método de Taylor de orden 2 para aproximar las soluciones para cada uno de los siguientes problemas de valor inicial.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### EJERCICIO A)

# %%
# %autoreload 2
from ODE import ODE_euler_nth
from math import exp
f_a= lambda t, y: t * exp(3 * t) - 2 * y
f_ap = lambda t, y: exp(3 * t) * (1 + 3 * t) - 2 * f_a(t, y)
f_2ap = lambda t, y: 3 * exp(3 * t) * (3 * t + 2) - 2 * f_ap(t, y)
a = 0
b = 1
y_t0 = 0
N = int((b - a) / 0.5)
ys_nth,ts_nth, h = ODE_euler_nth(a=a, b=b, y_t0=y_t0, f=f_a, N=10,f_derivatives=[f_ap])
ys_nth
# Out:
# [0,
#  0.005000000000000001,
#  0.02502281151742805,
#  0.06789379425444425,
#  0.14544842484587298,
#  0.27531320374223367,
#  0.48345394861307034,
#  0.8078082654427979,
#  1.3034471157996546,
#  2.0498893328328194,
#  3.1614425595477584]

# %%
import matplotlib.pyplot as plt

plt.plot(ts_nth, ys_nth, marker="o", linestyle=":", label="Método de Taylor de 2do orden")
plt.xlabel("Tiempo")
plt.ylabel("Y")
plt.title("Metodo de Taylor De Orden 2")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO B)

# %%
# %autoreload 2
from ODE import ODE_euler_nth
f_b= lambda t, y:  1 + (t - y)**2
f_bp = lambda t, y:  2 * (t - y) * (1 - f_b(t, y))
f_2bp = lambda t, y: 2 * (1 - f_b(t, y)) * (1 - f_bp(t, y) - f_b(t, y) * f_bp(t, y))
a = 2
b = 3
y_t0 = 1
N = int((b - a) / 0.5)
ys_nth,ts_nth, h = ODE_euler_nth(a=a, b=b, y_t0=y_t0, f=f_b, N=10,f_derivatives=[f_bp])
ys_nth
# Out:
# [1,
#  1.19,
#  1.36527429,
#  1.5291348977144272,
#  1.6839774634376887,
#  1.831575327148175,
#  1.9732680165644025,
#  2.110085555242049,
#  2.2428325637792974,
#  2.3721464731716617,
#  2.4985386529216678]

# %%
import matplotlib.pyplot as plt

plt.plot(ts_nth, ys_nth, marker="o", linestyle=":", label="Método de Taylor de 2do orden")
plt.xlabel("Tiempo")
plt.ylabel("Y")
plt.title("Metodo de Taylor De Orden 2")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO C)

# %%
# %autoreload 2
from ODE import ODE_euler_nth
f_c= lambda t, y:  1 + y / t
f_cp = lambda t, y:  -y / t**2 + f_c(t, y) / t
f_2cp = lambda t, y: -f_cp(t, y) / t**2 + f_cp(t, y) / t
a = 1
b = 2
y_t0 = 2
N = int((b - a) / 0.25)
ys_nth,ts_nth, h = ODE_euler_nth(a=a, b=b, y_t0=y_t0, f=f_c, N=10,f_derivatives=[f_cp])
ys_nth
# Out:
# [2,
#  2.305,
#  2.619090909090909,
#  2.9415151515151514,
#  3.2716317016317014,
#  3.6088911088911084,
#  3.9528171828171823,
#  4.302993256743256,
#  4.659051683610506,
#  5.020665666033311,
#  5.387542806350854]

# %%
import matplotlib.pyplot as plt

plt.plot(ts_nth, ys_nth, marker="o", linestyle=":", label="Método de Taylor de 2do orden")
plt.xlabel("Tiempo")
plt.ylabel("Y")
plt.title("Metodo de Taylor De Orden 2")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO D)

# %%
# %autoreload 2
from ODE import ODE_euler_nth
from math import cos, sin
f_d= lambda t, y: cos(2 * t) + sin(3 * t)
f_dp = lambda t, y:  -2 * sin(2 * t) + 3 * cos(3 * t)
f_2dp = lambda t, y: -4 * cos(2 * t) - 9 * sin(3 * t)
a = 1
b = 2
y_t0 = 2
N = int((b - a) / 0.25)
ys_nth,ts_nth, h = ODE_euler_nth(a=a, b=b, y_t0=y_t0, f=f_d, N=10,f_derivatives=[f_dp])
ys_nth
# Out:
# [2,
#  1.948554455434009,
#  1.8510326137073208,
#  1.7128351897731873,
#  1.5423257002366784,
#  1.3502420951067842,
#  1.1489166966081694,
#  0.9513669843309775,
#  0.7703307740012213,
#  0.6173240811842962,
#  0.5017980264151056]

# %%
import matplotlib.pyplot as plt

plt.plot(ts_nth, ys_nth, marker="o", linestyle=":", label="Método de Taylor de 2do orden")
plt.xlabel("Tiempo")
plt.ylabel("Y")
plt.title("Metodo de Taylor De Orden 2")
plt.legend()
plt.show()

# %% [markdown]
# ### 7. Repita el ejercicio 6 con el método de Taylor de orden 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### EJERICICIO A)

# %%
# %autoreload 2
from ODE import ODE_euler_nth
from math import exp
f_a= lambda t, y: t * exp(3 * t) - 2 * y
f_ap = lambda t, y: exp(3 * t) * (1 + 3 * t) - 2 * f_a(t, y)
f_2ap = lambda t, y: 3 * exp(3 * t) * (3 * t + 2) - 2 * f_ap(t, y)
f_3ap = lambda t, y: 9 * exp(3 * t) * (3 * t + 5) - 2 * f_2ap(t, y)
f_4ap = lambda t, y: 27 * exp(3 * t) * (3 * t + 14) - 2 * f_3ap(t, y)
a = 0
b = 1
y_t0 = 0
N = int((b - a) / 0.5)
ys_nth,ts_nth, h = ODE_euler_nth(a=a, b=b, y_t0=y_t0, f=f_a, N=10,f_derivatives=[f_ap])
ys_nth
# Out:
# [0,
#  0.005000000000000001,
#  0.02502281151742805,
#  0.06789379425444425,
#  0.14544842484587298,
#  0.27531320374223367,
#  0.48345394861307034,
#  0.8078082654427979,
#  1.3034471157996546,
#  2.0498893328328194,
#  3.1614425595477584]

# %%
import matplotlib.pyplot as plt

plt.plot(ts_nth, ys_nth, marker="o", linestyle=":", label="Método de Taylor hasta la Cuarta Derivada")
plt.xlabel("Tiempo")
plt.ylabel("Y")
plt.title("Metodo de Taylor De Orden 4")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO B)

# %%
# %autoreload 2
from ODE import ODE_euler_nth
f_b= lambda t, y:  1 + (t - y)**2
f_bp = lambda t, y:  2 * (t - y) * (1 - f_b(t, y))
f_2bp = lambda t, y: 2 * (1 - f_b(t, y)) * (1 - f_bp(t, y) - f_b(t, y) * f_bp(t, y))
f_3bp = lambda t, y: -4 * (t - y) * f_2bp(t, y)
f_4bp = lambda t, y: 8 * (1 - f_b(t, y)) * f_2bp(t, y)
a = 2
b = 3
y_t0 = 1
N = int((b - a) / 0.5)
ys_nth,ts_nth, h = ODE_euler_nth(a=a, b=b, y_t0=y_t0, f=f_b, N=10,f_derivatives=[f_bp])
ys_nth
# Out:
# [1,
#  1.19,
#  1.36527429,
#  1.5291348977144272,
#  1.6839774634376887,
#  1.831575327148175,
#  1.9732680165644025,
#  2.110085555242049,
#  2.2428325637792974,
#  2.3721464731716617,
#  2.4985386529216678]

# %%
import matplotlib.pyplot as plt

plt.plot(ts_nth, ys_nth, marker="o", linestyle=":", label="Método de Taylor hasta la Cuarta Derivada")
plt.xlabel("Tiempo")
plt.ylabel("Y")
plt.title("Metodo de Taylor De Orden 4")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO C)

# %%
# %autoreload 2
from ODE import ODE_euler_nth
f_c= lambda t, y:  1 + y / t
f_cp = lambda t, y:  -y / t**2 + f_c(t, y) / t
f_2cp = lambda t, y: -f_cp(t, y) / t**2 + f_cp(t, y) / t
f_3cp = lambda t, y: -f_2cp(t, y) / t**2 + f_2cp(t, y) / t
f_4cp = lambda t, y: -f_3cp(t, y) / t**2 + f_3cp(t, y) / t
a = 1
b = 2
y_t0 = 2
N = int((b - a) / 0.25)
ys_nth,ts_nth, h = ODE_euler_nth(a=a, b=b, y_t0=y_t0, f=f_c, N=10,f_derivatives=[f_cp])
ys_nth
# Out:
# [2,
#  2.305,
#  2.619090909090909,
#  2.9415151515151514,
#  3.2716317016317014,
#  3.6088911088911084,
#  3.9528171828171823,
#  4.302993256743256,
#  4.659051683610506,
#  5.020665666033311,
#  5.387542806350854]

# %%
import matplotlib.pyplot as plt

plt.plot(ts_nth, ys_nth, marker="o", linestyle=":", label="Método de Taylor hasta la Cuarta Derivada")
plt.xlabel("Tiempo")
plt.ylabel("Y")
plt.title("Metodo de Taylor De Orden 4")
plt.legend()
plt.show()

# %% [markdown]
# #### EJERCICIO D)

# %%
# %autoreload 2
from ODE import ODE_euler_nth
from math import cos, sin
f_d= lambda t, y: cos(2 * t) + sin(3 * t)
f_dp = lambda t, y:  -2 * sin(2 * t) + 3 * cos(3 * t)
f_2dp = lambda t, y: -4 * cos(2 * t) - 9 * sin(3 * t)
f_3dp = lambda t, y: 8 * sin(2 * t) - 27 * cos(3 * t)
f_4dp = lambda t, y: 16 * cos(2 * t) + 81 * sin(3 * t)
a = 1
b = 2
y_t0 = 2
N = int((b - a) / 0.25)
ys_nth,ts_nth, h = ODE_euler_nth(a=a, b=b, y_t0=y_t0, f=f_d, N=10,f_derivatives=[f_dp])
ys_nth
# Out:
# [2,
#  1.948554455434009,
#  1.8510326137073208,
#  1.7128351897731873,
#  1.5423257002366784,
#  1.3502420951067842,
#  1.1489166966081694,
#  0.9513669843309775,
#  0.7703307740012213,
#  0.6173240811842962,
#  0.5017980264151056]

# %%
import matplotlib.pyplot as plt

plt.plot(ts_nth, ys_nth, marker="o", linestyle=":", label="Método de Taylor hasta la Cuarta Derivada")
plt.xlabel("Tiempo")
plt.ylabel("Y")
plt.title("Metodo de Taylor De Orden 4")
plt.legend()
plt.show()
