# %% [markdown]
# #### **Escuela Politecnica Nacional del Ecuador**
# #### **Nombre:** Moisés Pineda
# #### **Fecha:** 07/06/2025

# %% [markdown]
# #### **[Tarea 08] Ejercicios Unidad 03-C mínimos cuadrados**

# %% [markdown]
# #### **Repositorio:** https://github.com/SantiagoTmg/Metodos_Numericos_GRCC1/tree/main/Tareas/%5BTarea%2008%5D%20Ejercicios%20Unidad%2003-C%20m%C3%ADnimos%20cuadrados

# %% [markdown]
# ##### **CONJUNTO DE EJERCICIOS**

# %% [markdown]
# ##### **1. Dados los datos:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### **1a.	Construya el polinomio de mínimos cuadrados de grado 1 y calcule el error.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Datos
x_vals = [4.0, 4.2, 4.5, 4.7, 5.1, 5.5, 5.9, 6.3, 6.8, 7.1]
y_vals = [102.56, 130.11, 113.18, 142.05, 167.53, 195.14, 224.87, 256.73, 299.50, 326.72]

# Definición de la función lineal
def linear_func(x, slope, intercept):
    return slope * x + intercept

# Ajuste de parámetros
params, _ = curve_fit(linear_func, x_vals, y_vals)
slope, intercept = params

# Creación de la función ajustada
def fitted_func(x):
    return slope * x + intercept

# Calcular puntos de la línea ajustada
x_interp = np.linspace(3, 8, 100)
y_interp = fitted_func(x_interp)

# Cálculo del error cuadrático
def calculate_squared_error(observed, predicted_func, x_data):
    total_error = 0
    for i in range(len(observed)):
        total_error += (observed[i] - predicted_func(x_data[i])) ** 2
    return total_error

# Visualización
plt.scatter(x_vals, y_vals, color='blue', label="Datos")
plt.plot(x_interp, y_interp, color='red', label="Línea ajustada")
plt.title("Ajuste Lineal")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.legend()
plt.show()  

# Resultados
print(f'{round(slope, 3)} x + {round(intercept, 3)}')
print(f'Error: {calculate_squared_error(y_vals, fitted_func, x_vals)}')
# Out:
# 71.61 x + -191.572
# Error: 1058.8388862638922

# %% [markdown]
# ##### **1b.	Construya el polinomio de mínimos cuadrados de grado 2 y calcule el error.**

# %%
# Definir la función cuadrática
def quadratic_eq(x, b2, b1, b0):
    return b2 * x**2 + b1 * x + b0

# Ajuste del modelo cuadrático
coeffs, _ = curve_fit(quadratic_eq, x_vals, y_vals)
b2, b1, b0 = coeffs

# Crear la función ajustada
def fitted_quadratic(x):
    return b2 * x**2 + b1 * x + b0

# Generar datos interpolados
x_fit = np.linspace(3, 8, 100)
y_fit = fitted_quadratic(x_fit)


# Graficar los datos y la curva ajustada
plt.scatter(x_vals, y_vals, color='blue', label="Datos")
plt.plot(x_fit, y_fit, color='red', label="Curva ajustada")
plt.title("Ajuste Cuadrático")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)
plt.legend()
plt.show()

# Imprimir resultados
print(f'{round(b2, 3)} x^2 + {round(b1, 3)} x + {round(b0, 3)}')
print(f'Error: {calculate_squared_error(y_vals, fitted_quadratic, x_vals)}')
# Out:
# 8.217 x^2 + -19.309 x + 51.001
# Error: 551.6562001170316

# %% [markdown]
# ##### **1c.	Construya el polinomio de mínimos cuadrados de grado 3 y calcule el error.**

# %%
# Definición de la función cúbica
def cubic_function(x, coef3, coef2, coef1, coef0):
    return coef3 * x**3 + coef2 * x**2 + coef1 * x + coef0

# Ajuste del modelo
coefficients, _ = curve_fit(cubic_function, x_vals, y_vals)
coef3, coef2, coef1, coef0 = coefficients

# Definir la función ajustada
def adjusted_cubic(x):
    return coef3 * x**3 + coef2 * x**2 + coef1 * x + coef0

# Generar valores interpolados
x_interp = np.linspace(3, 8, 100)
y_interp = adjusted_cubic(x_interp)

# Graficar los datos y la curva ajustada
plt.scatter(x_vals, y_vals, color="blue", label="Datos")
plt.plot(x_interp, y_interp, color="red", label="Curva ajustada")
plt.title("Ajuste Cúbico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)
plt.legend()
plt.show()

# Imprimir resultados
print(f'{round(coef3, 3)} x^3 + {round(coef2, 3)} x^2 + {round(coef1, 3)} x + {round(coef0, 3)}')
print(f'Error: {calculate_squared_error(y_vals, adjusted_cubic, x_vals)}')
# Out:
# -2.607 x^3 + 51.561 x^2 + -254.874 x + 469.162
# Error: 518.3830647406845

# %% [markdown]
# ##### **1d.	Construya el polinomio de mínimos cuadrados de la forma be^ax y calcule el error.**

# %%
# Definir la función exponencial
def exponential_func(x, c1, c2):
    return c1 * np.exp(c2 * x)

# Ajustar el modelo exponencial
coefficients, _ = curve_fit(exponential_func, x_vals, y_vals)
c1, c2 = coefficients

# Crear la función ajustada
def fitted_exponential(x):
    return c1 * np.exp(c2 * x)

# Generar valores interpolados para graficar
x_values = np.linspace(3, 8, 100)
y_values = fitted_exponential(x_values)

# Graficar los puntos y la curva ajustada
plt.scatter(x_vals, y_vals, color="red", label="Datos")
plt.plot(x_values, y_values, color="blue", label="Curva ajustada")
plt.title("Ajuste Exponencial")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)
plt.legend()
plt.show()

# Imprimir resultados
print(f'{round(c1, 3)} * e^({round(c2, 3)} * x)')
print(f'Error: {calculate_squared_error(y_vals, fitted_exponential, x_vals)}')
# Out:
# 26.841 * e^(0.355 * x)
# Error: 743.6215913505172

# %% [markdown]
# ##### **1e	Construya el polinomio de mínimos cuadrados de la forma bx^a y calcule el error.**

# %%
# Definir la función potencial
def power_function(x, coef, exponent):
    return coef * x**exponent

# Ajustar los datos al modelo
params, _ = curve_fit(power_function, x_vals, y_vals)
coef, exponent = params

# Crear la función ajustada
def fitted_power_function(x):
    return coef * x**exponent

# Generar puntos para la curva ajustada
x_fit = np.linspace(3, 8, 100)
y_fit = fitted_power_function(x_fit)

# Graficar los datos y el ajuste
plt.scatter(x_vals, y_vals, color="red", label="Datos")
plt.plot(x_fit, y_fit, color="blue", label="Curva ajustada")
plt.title("Ajuste Potencial")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.legend()
plt.grid(True)
plt.show()

# Mostrar resultados
print(f'{round(coef, 3)} * x^{round(exponent, 3)}')
print(f'Error: {calculate_squared_error(y_vals, fitted_power_function, x_vals)}')
# Out:
# 6.284 * x^2.015
# Error: 572.5817542056742

# %% [markdown]
# ##### **2.	Repita el ejercicio 5 para los siguientes datos.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### **2a.	Construya el polinomio de mínimos cuadrados de grado 1 y calcule el error.**

# %%
# Datos
x_points = [0.2, 0.3, 0.6, 0.9, 1.1, 1.3, 1.4, 1.6]
y_points = [0.050446, 0.098426, 0.33277, 0.72660, 1.0972, 1.5697, 1.8487, 2.5015]

# Ajuste de parámetros
params, _ = curve_fit(linear_func, x_points, y_points)
slope, intercept = params

# Calcular puntos de la línea ajustada
x_interp = np.linspace(0, 2, 100)
y_interp = fitted_func(x_interp)

# Visualización
plt.scatter(x_points, y_points, color='blue', label="Datos")
plt.plot(x_interp, y_interp, color='red', label="Línea ajustada")
plt.title("Ajuste Lineal")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.legend()
plt.show()  

# Resultados
print(f'{round(slope, 3)} x + {round(intercept, 3)}')
print(f'Error: {calculate_squared_error(y_points, fitted_func, x_points)}')
# Out:
# 1.666 x + -0.512
# Error: 0.3355898557594882

# %% [markdown]
# ##### **2b.	Construya el polinomio de mínimos cuadrados de grado 2 y calcule el error.**

# %%
# Ajuste del modelo cuadrático
coeffs, _ = curve_fit(quadratic_eq, x_points, y_points)
b2, b1, b0 = coeffs

# Generar datos interpolados
x_fit = np.linspace(0, 2, 100)
y_fit = fitted_quadratic(x_fit)

# Graficar los datos y la curva ajustada
plt.scatter(x_points, y_points, color='blue', label="Datos")
plt.plot(x_fit, y_fit, color='red', label="Curva ajustada")
plt.title("Ajuste Cuadrático")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)
plt.legend()
plt.show()

# Imprimir resultados
print(f'{round(b2, 3)} x^2 + {round(b1, 3)} x + {round(b0, 3)}')
print(f'Error: {calculate_squared_error(y_points, fitted_quadratic, x_points)}')
# Out:
# 1.129 x^2 + -0.311 x + 0.085
# Error: 0.002419914929426781

# %% [markdown]
# ##### **2c.	Construya el polinomio de mínimos cuadrados de grado 3 y calcule el error.**

# %%
# Ajuste del modelo
coefficients, _ = curve_fit(cubic_function, x_points, y_points)
coef3, coef2, coef1, coef0 = coefficients

# Generar valores interpolados
x_interp = np.linspace(2, 0, 100)
y_interp = adjusted_cubic(x_interp)

# Graficar los datos y la curva ajustada
plt.scatter(x_points, y_points, color="blue", label="Datos")
plt.plot(x_interp, y_interp, color="red", label="Curva ajustada")
plt.title("Ajuste Cúbico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)
plt.legend()
plt.show()

# Imprimir resultados
print(f'{round(coef3, 3)} x^3 + {round(coef2, 3)} x^2 + {round(coef1, 3)} x + {round(coef0, 3)}')
print(f'Error: {calculate_squared_error(y_points, adjusted_cubic, x_points)}')
# Out:
# 0.266 x^3 + 0.403 x^2 + 0.248 x + -0.018
# Error: 5.074671555628466e-06

# %% [markdown]
# ##### **2d.	Construya el polinomio de mínimos cuadrados de la forma be^ax y calcule el error.**

# %%
# Ajustar el modelo exponencial
coefficients, _ = curve_fit(exponential_func, x_points, y_points)
c1, c2 = coefficients

# Generar valores interpolados para graficar
x_values = np.linspace(0, 2, 100)
y_values = fitted_exponential(x_values)

# Graficar los puntos y la curva ajustada
plt.scatter(x_points, y_points, color="red", label="Datos")
plt.plot(x_values, y_values, color="blue", label="Curva ajustada")
plt.title("Ajuste Exponencial")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)
plt.legend()
plt.show()

# Imprimir resultados
print(f'{round(c1, 3)} * e^({round(c2, 3)} * x)')
print(f'Error: {calculate_squared_error(y_points, fitted_exponential, x_points)}')
# Out:
# 0.133 * e^(1.858 * x)
# Error: 0.06798773800157852

# %% [markdown]
# ##### **2e	Construya el polinomio de mínimos cuadrados de la forma bx^a y calcule el error.**

# %%
# Ajustar los datos al modelo
params, _ = curve_fit(power_function, x_points, y_points)
coef, exponent = params

# Generar puntos para la curva ajustada
x_fit = np.linspace(0, 2, 100)
y_fit = fitted_power_function(x_fit)

# Graficar los datos y el ajuste
plt.scatter(x_points, y_points, color="red", label="Datos")
plt.plot(x_fit, y_fit, color="blue", label="Curva ajustada")
plt.title("Ajuste Potencial")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.legend()
plt.grid(True)
plt.show()

# Mostrar resultados
print(f'{round(coef, 3)} * x^{round(exponent, 3)}')
print(f'Error: {calculate_squared_error(y_points, fitted_power_function, x_points)}')
# Out:
# 0.906 * x^2.143
# Error: 0.0034875321141967044

# %% [markdown]
# ##### **3.	La siguiente tabla muestra los promedios de puntos del colegio de 20 especialistas en matemáticas y ciencias computacionales, junto con las calificaciones que recibieron estos estudiantes en la parte de matemáticas de la prueba ACT (Programa de Pruebas de Colegios Americanos) mientras estaban en secundaria. Grafique estos datos y encuentre la ecuación de la recta por mínimos cuadrados para estos datos.**

# %%
# Datos de entrada
ACT_scores = [28, 25, 28, 27, 28, 33, 28, 29, 23, 27, 29, 28, 27, 29, 21, 28, 28, 26, 30, 24]
average_scores = [3.84, 3.21, 3.23, 3.63, 3.75, 3.20, 3.41, 3.38, 3.53, 2.03, 3.75, 3.65, 3.87, 3.75, 1.66, 3.12, 2.96, 2.92, 3.10, 2.81]

# Ajuste de parámetros
params, _ = curve_fit(linear_func, ACT_scores, average_scores)
slope, intercept = params

# Calcular puntos de la línea ajustada
x_interp = np.linspace(20, 34, 100)
y_interp = fitted_func(x_interp)

# Visualización
plt.scatter(ACT_scores, average_scores, color='blue', label="Datos")
plt.plot(x_interp, y_interp, color='red', label="Línea ajustada")
plt.title("Ajuste Lineal")
plt.xlabel("Puntaje ACT")
plt.ylabel("Promedio Academico")
plt.grid(True)
plt.legend()
plt.show()  

# Resultados
print(f'{round(slope, 3)} x + {round(intercept, 3)}')
print(f'Error: {calculate_squared_error(average_scores, fitted_func, ACT_scores)}')
# Out:
# 0.101 x + 0.487
# Error: 5.048705616224648

# %% [markdown]
# ##### **4.	El siguiente conjunto de datos, presentando el Subcomité Antimonopolio del Senado, muestra las características comparativas de supervivencia durante un choque de automóviles de diferentes clases. Encuentre la recta por mínimos cuadrados que aproxima estos datos (la tabla muestra el porcentaje de vehículos que participaron en un accidente en los que la lesión más grave fue fatal o seria)**

# %%
# Datos de entrada
average_weights = [4800, 3700, 3400, 2800, 1900]
accident_percentages = [3.1, 4, 5.2, 6.4, 9.6]

# Ajuste de parámetros
params, _ = curve_fit(linear_func, average_weights, accident_percentages)
slope, intercept = params

# Calcular puntos de la línea ajustada
x_interp = np.linspace(1800, 5000, 100)
y_interp = fitted_func(x_interp)

# Visualización
plt.scatter(average_weights, accident_percentages, color='blue', label="Datos")
plt.plot(x_interp, y_interp, color='red', label="Línea ajustada")
plt.title("Ajuste Lineal")
plt.xlabel("Peso Promedio")
plt.ylabel("Porcentaje de Accidentes")
plt.grid(True)
plt.legend()
plt.show()  

# Resultados
print(f'{round(slope, 3)} x + {round(intercept, 3)}')
print(f'Error: {calculate_squared_error(accident_percentages, fitted_func, average_weights)}')
# Out:
# -0.002 x + 13.146
# Error: 2.0591356957649083
