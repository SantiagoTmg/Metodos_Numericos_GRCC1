# %% [markdown]
# # **Taller 1**
# #### **Nombre:** Moisés Pineda
# #### **Fecha:** 28/04/2025

# %% [markdown]
# #### **Algoritmo 03**

# %% [markdown]
# ![algo03.png](attachment:algo03.png)

# %%
def alg_03(n):
    if n == 0:
        return 0
    else:
        x = 0
        y = 1
        for i in range(1, n):
            z = x + y
            x = y
            y = z
        return y

# %%
# Caso de prueba
n = 11
print("Y es igual a:", alg_03(n))
# Out:
# Y es igual a: 89
