# %% [markdown]
# # **Taller 1**
# #### **Nombre:** Moisés Pineda
# #### **Fecha:** 28/04/2025

# %% [markdown]
# ##### Algoritmo01

# %% [markdown]
# ![algo01.png](attachment:algo01.png)

# %%
def alg_01(N, X):
    SUM = 0
    for i in range(N):
        SUM += X[i]
    return SUM

# %%
# Casos de prueba
X1 = list(range(100))  # Caso 1
print("Resultado caso 1:", alg_01(len(X1), X1))

X2 = [1, 1/2, 1/4]  # Caso 2
print("Resultado caso 2:", alg_01(len(X2), X2))

X3 = [1/2**x for x in range(15)]
print(X3)
r = alg_01(len(X3), X3)
print(r)
f"{2-r}"
# Out:
# Resultado caso 1: 4950
# Resultado caso 2: 1.75
# [1.0, 0.5, 0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625, 0.001953125, 0.0009765625, 0.00048828125, 0.000244140625, 0.0001220703125, 6.103515625e-05]
# 1.99993896484375
# '6.103515625e-05'

# %% [markdown]
# ![quizz2.png](attachment:quizz2.png)

# %% [markdown]
# ##### **Respuesta ->** El limite de la serie es 2

# %% [markdown]
# ![quizz3.png](attachment:quizz3.png)

# %%
# Resolucion quizz
X2 = [1/2**x for x in range(6)]  # 5 elementos como minimo para que el error relativo este dentro de 10^-1
X4 = round(alg_01(len(X2), X2))
error_relativo = abs( alg_01(len(X2), X2) - X4)/ abs(alg_01(len(X2), X2))
print(error_relativo)
# Out:
# 0.015873015873015872
