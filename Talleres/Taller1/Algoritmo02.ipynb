# %% [markdown]
# # **Taller 1**
# #### **Nombre:** Moisés Pineda
# #### **Fecha:** 28/04/2025

# %% [markdown]
# ### **Algoritmo02**

# %% [markdown]
# ![algo02.png](attachment:algo02.png)

# %%
def alg_02(a):
    n = len(a)
    count = 0
    for i in range(n):
        swapped = False
        for j in range(1, n - i):
            if a[j] < a[j - 1]:  # Comparación de elementos adyacentes
                a[j], a[j - 1] = a[j - 1], a[j]  # Intercambio de valores
                swapped = True
                count += 1  # Contador de intercambios
        if not swapped:  # Si no hubo intercambios, la lista está ordenada
            break
    return a, count  # Retorna la lista ordenada y el número de intercambios

# %% [markdown]
# ![quizz4.png](attachment:quizz4.png)

# %% [markdown]
# ##### **Respuesta ->** Ordena el vector

# %% [markdown]
# ![quizz5.png](attachment:quizz5.png)

# %%
# Caso de prueba
lista = [5, 4, 3, 2, 1]
print("Lista original:", lista)
print("Lista ordenada y el número de comparaciones:", alg_02(lista))
# Out:
# Lista original: [5, 4, 3, 2, 1]
# Lista ordenada y el número de comparaciones: ([1, 2, 3, 4, 5], 10)
